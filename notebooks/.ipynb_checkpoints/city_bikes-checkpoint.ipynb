# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import pandas as pd
import json

# %%
# Query the entire CityBikes database and save the returned response in JSON format as it is easier to parse through
citybike_json = requests.get('http://api.citybik.es/v2/networks?fields=name.href.location').json()

# %%
def network_finder(city:str):
    """
    Returns specific network ID in string format for the city if found.
    City: single string containing the name of the city.
    """
    for network in citybike_json['networks']:
        if city.lower() in network['location']['city'].lower():
            return network['href']
    print('City not found')

# %%
# City of Hamilton was chosen for having not too many bike stations (important for not exceeding API call limits)
hamilton_network = network_finder('Hamilton')

# %%
# Save the response from the CityBikes API in JSON format
hamilton_citybike_json = requests.get(f'http://api.citybik.es{hamilton_network}').json()

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
hamilton_citybike_json['network']['stations']
# Out:
# [{'empty_slots': 6,
#   'extra': {'address': '15 Hess Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_802'},
#   'free_bikes': 6,
#   'id': '45dbb0009135e465f49f054517cbe74d',
#   'latitude': 43.259125842121065,
#   'longitude': -79.87721174955368,
#   'name': 'Hess at king',
#   'timestamp': '2023-08-30T01:32:48.695000Z'},
#  {'empty_slots': 23,
#   'extra': {'address': 'Harbour Front Drive, North End, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_579'},
#   'free_bikes': 11,
#   'id': 'cd881edad122a75c57d94b381cdfc6c0',
#   'latitude': 43.269288276229105,
#   'longitude': -79.87132698297499,
#   'name': 'Bayfront Park',
#   'timestamp': '2023-08-30T01:32:48.697000Z'},
#  {'empty_slots': 25,
#   'extra': {'address': '325 Bay Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_578'},
#   'free_bikes': 0,
#   'id': '024a3edf037cb411d16acc08a7fcb954',
#   'latitude': 43.26785864558976,
#   'longitude': -79.8679232597351,
#   'name': 'Bay at Strachan',
#   'timestamp': '2023-08-30T01:32:48.698000Z'},
#  {'empty_slots': 9,
#   'extra': {'address': '177, Bay Street North, Hess Village, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_577'},
#   'free_bikes': 5,
#   'id': 'b933317ff2861c45aacbea4cbf4b541f',
#   'latitude': 43.263198441574474,
#   'longitude': -79.87180307507515,
#   'name': 'Bay at Mulberry',
#   'timestamp': '2023-08-30T01:32:48.698000Z'},
#  {'empty_slots': 10,
#   'extra': {'address': '58 Bay Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_575'},
#   'free_bikes': 7,
#   'id': '20dc109608315db09a8332d6e6940c75',
#   'latitude': 43.2561324863605,
#   'longitude': -79.8744987564414,
#   'name': 'City Hall',
#   'timestamp': '2023-08-30T01:32:48.700000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '100 Bold Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_574'},
#   'free_bikes': 11,
#   'id': 'a386509756e2c2e15483eaaf344fb412',
#   'latitude': 43.2538302267771,
#   'longitude': -79.8753935613187,
#   'name': 'Bay at Bold',
#   'timestamp': '2023-08-30T01:32:48.700000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '232 James Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_573'},
#   'free_bikes': 7,
#   'id': '3527ca2c4e22a011c0615126afce23d5',
#   'latitude': 43.2496354495324,
#   'longitude': -79.8720555723035,
#   'name': 'James S at Charlton',
#   'timestamp': '2023-08-30T01:32:48.701000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '40-48 Oxford Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_571'},
#   'free_bikes': 5,
#   'id': '337f37f6d8b9db34372c0cfe1a7d2595',
#   'latitude': 43.26456372689135,
#   'longitude': -79.8777937889099,
#   'name': 'Oxford at York',
#   'timestamp': '2023-08-30T01:32:48.702000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '80, Queen Street North, Hess Village, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_570'},
#   'free_bikes': 7,
#   'id': '8bd4d92cf10d53a1b69805e875ca2001',
#   'latitude': 43.2618861338306,
#   'longitude': -79.877606006297,
#   'name': 'Queen at Peter',
#   'timestamp': '2023-08-30T01:32:48.703000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '144 West Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_712'},
#   'free_bikes': 4,
#   'id': '95c24984959b304fdb8bb3ab251810e9',
#   'latitude': 43.257877862291,
#   'longitude': -79.8561337635964,
#   'name': 'West at Cannon',
#   'timestamp': '2023-08-30T01:32:48.704000Z'},
#  {'empty_slots': 33,
#   'extra': {'address': '88 Forsyth Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_894'},
#   'free_bikes': 2,
#   'id': '2a91db522d9c3f209772a8f35b8ee4e1',
#   'latitude': 43.26271404114188,
#   'longitude': -79.91580605506897,
#   'name': 'Forsyth at Sterling',
#   'timestamp': '2023-08-30T01:32:48.710000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '75-77 Gage Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2924'},
#   'free_bikes': 2,
#   'id': '1846562b60f9d9469c055fed1d84898e',
#   'latitude': 43.25112644429895,
#   'longitude': -79.82740849256516,
#   'name': 'Gage at Cannon - ERI11',
#   'timestamp': '2023-08-30T01:32:48.710000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '251 Duke Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_568'},
#   'free_bikes': 4,
#   'id': '630c0983a0b38edfc8772e7b45c8dab1',
#   'latitude': 43.2540651616154,
#   'longitude': -79.8819466027797,
#   'name': 'H.A.A.A. Park',
#   'timestamp': '2023-08-30T01:32:48.712000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '131-133 Hess Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_569'},
#   'free_bikes': 10,
#   'id': 'f5019394e945492c7644ad38a0db33ce',
#   'latitude': 43.255383107655966,
#   'longitude': -79.87889617681503,
#   'name': 'Hunter at Hess',
#   'timestamp': '2023-08-30T01:32:48.713000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '44 Dunsmure Road, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2923'},
#   'free_bikes': 4,
#   'id': '39c08c3439e8b49ff26c7d7d9dfe6ed1',
#   'latitude': 43.24943274108067,
#   'longitude': -79.8388883471489,
#   'name': 'Dunsmure at Sherman - ERI10',
#   'timestamp': '2023-08-30T01:32:48.714000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '304 Dunsmure Road, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2922'},
#   'free_bikes': 7,
#   'id': '18ed716ef5002294aaa2ff40b3fd8921',
#   'latitude': 43.24634382646498,
#   'longitude': -79.82685998082161,
#   'name': 'King at Dunsmure - ERI09',
#   'timestamp': '2023-08-30T01:32:48.714000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '64, Locke Street North, Hess Village, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_564'},
#   'free_bikes': 7,
#   'id': '91fa730ae5a6c44945e897d27119a5f2',
#   'latitude': 43.2628018805713,
#   'longitude': -79.8827367298478,
#   'name': 'Locke at Napier',
#   'timestamp': '2023-08-30T01:32:48.715000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '460 York Boulevard, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_565'},
#   'free_bikes': 9,
#   'id': '5abbf86662e318c18e2e8eb448f2e5c8',
#   'latitude': 43.2659146108256,
#   'longitude': -79.8819495909127,
#   'name': 'York at Inchbury',
#   'timestamp': '2023-08-30T01:32:48.716000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': 'ABERDEEN at SPRUCESIDE, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_566'},
#   'free_bikes': 7,
#   'id': '17dcbb977faa236652d5f039ee54eab5',
#   'latitude': 43.2488085584277,
#   'longitude': -79.8836993988543,
#   'name': 'Aberdeen at Queen',
#   'timestamp': '2023-08-30T01:32:48.717000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '9-11 Dundurn Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_560'},
#   'free_bikes': 11,
#   'id': 'dff4dd3a682e5fd806a7004a34f166e4',
#   'latitude': 43.26240933566922,
#   'longitude': -79.88798081874847,
#   'name': 'King at Dundurn',
#   'timestamp': '2023-08-30T01:32:48.718000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '91 Dundurn Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_559'},
#   'free_bikes': 2,
#   'id': '34e98e408d0478448d774f24fbb9105a',
#   'latitude': 43.25966301112219,
#   'longitude': -79.8892092704773,
#   'name': 'Main at Dundurn',
#   'timestamp': '2023-08-30T01:32:48.723000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '229-233 Dundurn Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_558'},
#   'free_bikes': 6,
#   'id': 'd6c7c14e47cd30a743d379e7e544f2f2',
#   'latitude': 43.2548127612063,
#   'longitude': -79.8909067737901,
#   'name': 'Dundurn St S',
#   'timestamp': '2023-08-30T01:32:48.723000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': 'Matthews Hall, Scholars Road, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_625'},
#   'free_bikes': 12,
#   'id': '5fd1db2bc0ce16dcc7c983c80fb8ff34',
#   'latitude': 43.262460120020584,
#   'longitude': -79.92224670946598,
#   'name': 'McMaster Mary Keyes',
#   'timestamp': '2023-08-30T01:32:48.724000Z'},
#  {'empty_slots': 21,
#   'extra': {'address': 'CIBC, University Avenue, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_624'},
#   'free_bikes': 10,
#   'id': 'd87ad3e6e7e39c8680e5da273289126a',
#   'latitude': 43.26053126154136,
#   'longitude': -79.91824820637703,
#   'name': 'McMaster Health Sciences',
#   'timestamp': '2023-08-30T01:32:48.725000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '2000 College Court, McMaster University, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_623'},
#   'free_bikes': 10,
#   'id': 'd933c4e54010753b1c85727ba6e203a2',
#   'latitude': 43.2599690032886,
#   'longitude': -79.922358671032,
#   'name': 'McMaster Arthur Bourns',
#   'timestamp': '2023-08-30T01:32:48.725000Z'},
#  {'empty_slots': 19,
#   'extra': {'address': 'Main Street West, Emerson at Main, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_622'},
#   'free_bikes': 1,
#   'id': '4bc9ff88b1ceaa64a384fa9731ae8d01',
#   'latitude': 43.258038792898375,
#   'longitude': -79.91978779435158,
#   'name': 'McMaster Emerson',
#   'timestamp': '2023-08-30T01:32:48.726000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': '78, Longwood Road North, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_551'},
#   'free_bikes': 11,
#   'id': 'dd521d8e002ed058f01ea5c1d6a899d7',
#   'latitude': 43.2662112220324,
#   'longitude': -79.8993094512,
#   'name': 'Longwood at Edgevale',
#   'timestamp': '2023-08-30T01:32:48.727000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': '881, King Street West, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_550'},
#   'free_bikes': 9,
#   'id': 'ef31eb281843d11149a891269f438331',
#   'latitude': 43.2630174571678,
#   'longitude': -79.9009418422827,
#   'name': 'Longwood at King',
#   'timestamp': '2023-08-30T01:32:48.728000Z'},
#  {'empty_slots': 9,
#   'extra': {'address': 'Chedoke Park, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_552'},
#   'free_bikes': 2,
#   'id': '4f4fb284d16149957dda0b5ea3fb8a61',
#   'latitude': 43.2460802627748,
#   'longitude': -79.90823779724,
#   'name': 'Chedoke Stairs',
#   'timestamp': '2023-08-30T01:32:48.729000Z'},
#  {'empty_slots': 15,
#   'extra': {'address': '175 Longwood Road South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_555'},
#   'free_bikes': 2,
#   'id': 'bd96d779c3e3b836ca90e548eee888a1',
#   'latitude': 43.25656885270854,
#   'longitude': -79.9011692404747,
#   'name': 'McMaster Innovation Park',
#   'timestamp': '2023-08-30T01:32:48.730000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '768, King Street West, McMaster Innovation Park, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_554'},
#   'free_bikes': 6,
#   'id': '7c7c2a29076e490b95bc735fbcaed460',
#   'latitude': 43.2621672804245,
#   'longitude': -79.8964982026467,
#   'name': 'Macklin at King',
#   'timestamp': '2023-08-30T01:32:48.731000Z'},
#  {'empty_slots': 13,
#   'extra': {'address': '330-346 Dundurn Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_557'},
#   'free_bikes': 10,
#   'id': '99ec29f3c8fe3433ed45611988e8ca4d',
#   'latitude': 43.251458458948996,
#   'longitude': -79.89265590906143,
#   'name': 'Dundurn at Aberdeen',
#   'timestamp': '2023-08-30T01:32:48.731000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '534, Dundurn Street South, Chedoke Park, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_556'},
#   'free_bikes': 7,
#   'id': '1fcd421afe5b8dcde4553554201a7ed2',
#   'latitude': 43.2465214141618,
#   'longitude': -79.8947787566411,
#   'name': 'Dundurn Stairs',
#   'timestamp': '2023-08-30T01:32:48.732000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': '11 Court Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2869'},
#   'free_bikes': 0,
#   'id': '6690c346b37fcd1b741875064926638a',
#   'latitude': 43.26547419149645,
#   'longitude': -79.94765996932983,
#   'name': 'Cootes Drive Dundas',
#   'timestamp': '2023-08-30T01:32:48.733000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '809 Desjardins Recreation Trail, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_765'},
#   'free_bikes': 4,
#   'id': '8601b4c3dfc470daf8d5e63b28b20e7f',
#   'latitude': 43.2729912871819,
#   'longitude': -79.8945270389426,
#   'name': 'Princess Point',
#   'timestamp': '2023-08-30T01:32:48.733000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '107 Pearl Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5402'},
#   'free_bikes': 4,
#   'id': 'ec51bdbd1936f333b917f2154087c814',
#   'latitude': 43.25650634283747,
#   'longitude': -79.88345324993132,
#   'name': 'Pearl Street Bridge',
#   'timestamp': '2023-08-30T01:32:48.736000Z'},
#  {'empty_slots': 13,
#   'extra': {'address': 'Hamilton Brantford Rail Trail, Emerson Street, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_546'},
#   'free_bikes': 4,
#   'id': '8d388d807755c747375a2b7c4b18eada',
#   'latitude': 43.2546745875963,
#   'longitude': -79.9208028150996,
#   'name': 'Rail Trail at Emerson',
#   'timestamp': '2023-08-30T01:32:48.736000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '955 King Street West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_544'},
#   'free_bikes': 11,
#   'id': '6f17e8701f57d4460774045411bcec7e',
#   'latitude': 43.262715994377196,
#   'longitude': -79.90359663963316,
#   'name': 'Westdale Library',
#   'timestamp': '2023-08-30T01:32:48.737000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '202, Emerson Street, University Gardens, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_545'},
#   'free_bikes': 10,
#   'id': '77030d658ee4dd5f9ad7a741fe3cdd79',
#   'latitude': 43.2521423210113,
#   'longitude': -79.9222158171462,
#   'name': 'Emerson at Whitney',
#   'timestamp': '2023-08-30T01:32:48.738000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '139, Sterling Street, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_542'},
#   'free_bikes': 3,
#   'id': '133e6840636162eef8f7c0e877071607',
#   'latitude': 43.2622271626907,
#   'longitude': -79.9133658840373,
#   'name': 'Sterling at Whitton',
#   'timestamp': '2023-08-30T01:32:48.739000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '71 Sterling Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_543'},
#   'free_bikes': 6,
#   'id': '3736ced2decabcac22ddf364fe1d5407',
#   'latitude': 43.26202552179778,
#   'longitude': -79.91026729345322,
#   'name': 'Sterling at Haddon',
#   'timestamp': '2023-08-30T01:32:48.739000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '26, Sanders Boulevard, University Gardens, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_540'},
#   'free_bikes': 11,
#   'id': 'a7f3ee3b05806c3e979202c0590d5179',
#   'latitude': 43.2599031676959,
#   'longitude': -79.9264810904732,
#   'name': 'Sanders at Hollywood',
#   'timestamp': '2023-08-30T01:32:48.740000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '1108 King Street West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_541'},
#   'free_bikes': 5,
#   'id': 'df7262645c8624531b1a34cf39c89771',
#   'latitude': 43.2605367847852,
#   'longitude': -79.9092948353051,
#   'name': 'King at Cline',
#   'timestamp': '2023-08-30T01:32:48.741000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': 'Hamilton Brantford Rail Trail, Emerson Street, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_548'},
#   'free_bikes': 5,
#   'id': 'b23eb87ed716fb2e4f127b9b893f29bc',
#   'latitude': 43.2535916384655,
#   'longitude': -79.9166152756283,
#   'name': 'Rail Trail at Stroud',
#   'timestamp': '2023-08-30T01:32:48.742000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '82 Newton Avenue, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_549'},
#   'free_bikes': 5,
#   'id': '2b42c682f103d65f546555b599e8cf52',
#   'latitude': 43.2585671813327,
#   'longitude': -79.90785866975784,
#   'name': 'Main at Columbia College',
#   'timestamp': '2023-08-30T01:32:48.742000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '6-8 Main Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2868'},
#   'free_bikes': 2,
#   'id': '3a13a5c31c7483e54a8c71af5a9b0668',
#   'latitude': 43.26595632543361,
#   'longitude': -79.95375394821166,
#   'name': 'King Street Dundas',
#   'timestamp': '2023-08-30T01:32:48.743000Z'},
#  {'empty_slots': 16,
#   'extra': {'address': '36 Hunter Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_631'},
#   'free_bikes': 1,
#   'id': 'dd00194c26112252a0123c2889671ae0',
#   'latitude': 43.25343546641674,
#   'longitude': -79.86948698759079,
#   'name': 'Hunter GO Centre',
#   'timestamp': '2023-08-30T01:32:48.744000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '80-92 Robinson Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_709'},
#   'free_bikes': 8,
#   'id': 'e3f950c764985f5663487f33c961e47d',
#   'latitude': 43.2515957745917,
#   'longitude': -79.8749090863127,
#   'name': 'Park at Robinson',
#   'timestamp': '2023-08-30T01:32:48.745000Z'},
#  {'empty_slots': 10,
#   'extra': {'address': '1150-1152 Main Street West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5333'},
#   'free_bikes': 0,
#   'id': '4f8e0eeb6b9c0a79a192d73ec6cfc98f',
#   'latitude': 43.25802547698811,
#   'longitude': -79.91383865476678,
#   'name': 'Main at Dalewood',
#   'timestamp': '2023-08-30T01:32:48.746000Z'},
#  {'empty_slots': 13,
#   'extra': {'address': '57 John Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_780'},
#   'free_bikes': 0,
#   'id': 'ad7d9eea49ccec4ac431465d5b6bc8a4',
#   'latitude': 43.254529435061336,
#   'longitude': -79.86718028783798,
#   'name': 'John at Main',
#   'timestamp': '2023-08-30T01:32:48.747000Z'},
#  {'empty_slots': 32,
#   'extra': {'address': '17A Cannon Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_945'},
#   'free_bikes': 0,
#   'id': '8c7e7edf96c59d7ec1d5abb24432e779',
#   'latitude': 43.25161474646046,
#   'longitude': -79.83134329318999,
#   'name': 'Stadium',
#   'timestamp': '2023-08-30T01:32:48.747000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '1686 Main Street West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_537'},
#   'free_bikes': 5,
#   'id': '43cf0e9fa1672920ce236fc613eee2e3',
#   'latitude': 43.2572539435115,
#   'longitude': -79.9342255404988,
#   'name': 'Osler at Main',
#   'timestamp': '2023-08-30T01:32:48.749000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '1850, Main Street West, University Gardens, Ancaster, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_536'},
#   'free_bikes': 4,
#   'id': 'cda78e5631d14cf607d59cc92cc6d424',
#   'latitude': 43.25205234935895,
#   'longitude': -79.93979036808014,
#   'name': 'Main at Whitney',
#   'timestamp': '2023-08-30T01:32:48.750000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '89-101 Osler Drive, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_535'},
#   'free_bikes': 5,
#   'id': '972059c18777939b2148f40fab59bb18',
#   'latitude': 43.2595496051254,
#   'longitude': -79.9426434441838,
#   'name': 'Osler at Grant',
#   'timestamp': '2023-08-30T01:32:48.750000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '272, Sherman Avenue North, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_1468'},
#   'free_bikes': 3,
#   'id': '46899650a9b5b0cfe2542ac52e9b7bec',
#   'latitude': 43.26044140942891,
#   'longitude': -79.83437284827232,
#   'name': '270 Sherman',
#   'timestamp': '2023-08-30T01:32:48.752000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '58, Sanders Boulevard, University Gardens, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_539'},
#   'free_bikes': 2,
#   'id': '50abdb177272576170d43b46892d2761',
#   'latitude': 43.25875372772543,
#   'longitude': -79.92979913949966,
#   'name': 'Sanders at Binkley',
#   'timestamp': '2023-08-30T01:32:48.753000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '377, Whitney Avenue, University Gardens, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_538'},
#   'free_bikes': 5,
#   'id': '0688d3f9058eef55341330755b661c61',
#   'latitude': 43.2518522355378,
#   'longitude': -79.9354198942367,
#   'name': 'Whitney at Lower Horning',
#   'timestamp': '2023-08-30T01:32:48.753000Z'},
#  {'empty_slots': 14,
#   'extra': {'address': '200 James Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_436'},
#   'free_bikes': 4,
#   'id': '0bf21f162a6d07a198f581d9993b28bf',
#   'latitude': 43.26181945279216,
#   'longitude': -79.86674308776855,
#   'name': 'James North at Mulberry',
#   'timestamp': '2023-08-30T01:32:48.754000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '44 Frid Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_921'},
#   'free_bikes': 8,
#   'id': '0941a8cf2073bf2c25c874ee9caf762f',
#   'latitude': 43.25940517059312,
#   'longitude': -79.89262372255325,
#   'name': 'Frid at Main',
#   'timestamp': '2023-08-30T01:32:48.755000Z'},
#  {'empty_slots': 13,
#   'extra': {'address': '20 King Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_435'},
#   'free_bikes': 3,
#   'id': 'a6ddd4ae5ba3af0edfa38b589f9d884c',
#   'latitude': 43.256316859398744,
#   'longitude': -79.86866354942322,
#   'name': 'Gore Park',
#   'timestamp': '2023-08-30T01:32:48.755000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '93, West Avenue South, Corktown, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_601'},
#   'free_bikes': 5,
#   'id': 'ae7ac15e55165e3cb5978b0bf082e779',
#   'latitude': 43.2494985579078,
#   'longitude': -79.859726111821,
#   'name': 'Stinson at West',
#   'timestamp': '2023-08-30T01:32:48.756000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '338, King William Street, Beasley, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_602'},
#   'free_bikes': 8,
#   'id': '6f4ab4aa1f8204cfd599a3d3c49b73fd',
#   'latitude': 43.254154362311304,
#   'longitude': -79.85582381486893,
#   'name': 'King William at Victoria',
#   'timestamp': '2023-08-30T01:32:48.758000Z'},
#  {'empty_slots': 10,
#   'extra': {'address': '16 Wentworth Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_605'},
#   'free_bikes': 2,
#   'id': '3d77891b65e6ced980cc683365a7b4cf',
#   'latitude': 43.25199038416551,
#   'longitude': -79.84910354018211,
#   'name': 'Wentworth at King',
#   'timestamp': '2023-08-30T01:32:48.758000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '451, Cannon Street East, Beasley, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_604'},
#   'free_bikes': 1,
#   'id': '5ea66dfb7598a1a4659227f1a4698ba5',
#   'latitude': 43.2559617394464,
#   'longitude': -79.8475054418754,
#   'name': 'Cannon at Wentworth - 96',
#   'timestamp': '2023-08-30T01:32:48.759000Z'},
#  {'empty_slots': 9,
#   'extra': {'address': '22 Haymarket Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_607'},
#   'free_bikes': 3,
#   'id': '352176e326772dbde256ff59c7e12df3',
#   'latitude': 43.2523698048509,
#   'longitude': -79.86883386969566,
#   'name': 'Haymarket at Hughson',
#   'timestamp': '2023-08-30T01:32:48.760000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '492 Bay Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_606'},
#   'free_bikes': 6,
#   'id': '768268c35a08c86dc7a819108035253f',
#   'latitude': 43.272362258983364,
#   'longitude': -79.86627101898192,
#   'name': 'Bay at Macaulay',
#   'timestamp': '2023-08-30T01:32:48.761000Z'},
#  {'empty_slots': 16,
#   'extra': {'address': '64 Rifle Range Road, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_830'},
#   'free_bikes': 0,
#   'id': 'eb652fc9347b78dbffc1e843889d9617',
#   'latitude': 43.2554850097816,
#   'longitude': -79.9298771288198,
#   'name': 'Rifle Range at Rail Trail',
#   'timestamp': '2023-08-30T01:32:48.765000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '22 Hill Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5426'},
#   'free_bikes': 5,
#   'id': '9a4ae5211ff86fec59b59975ee988554',
#   'latitude': 43.25672417073905,
#   'longitude': -79.88822355870525,
#   'name': 'Hill Street Park',
#   'timestamp': '2023-08-30T01:32:48.766000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '126 Catharine Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_527'},
#   'free_bikes': 7,
#   'id': 'fe1507c344d73062f43e013bdd6139a3',
#   'latitude': 43.25911119199103,
#   'longitude': -79.86361294984816,
#   'name': 'Seedworks',
#   'timestamp': '2023-08-30T01:32:48.768000Z'},
#  {'empty_slots': 14,
#   'extra': {'address': '190 Gage Avenue South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_614'},
#   'free_bikes': 10,
#   'id': 'e322c48bdbc2e5ad2e49c7296e26c237',
#   'latitude': 43.24344818701565,
#   'longitude': -79.83040988445282,
#   'name': 'Gage Park',
#   'timestamp': '2023-08-30T01:32:48.768000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '17, Delaware Avenue, Inch Park, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_612'},
#   'free_bikes': 9,
#   'id': 'c080ee1bfa65cf18eb5b5d75c07f3b8e',
#   'latitude': 43.2480454302898,
#   'longitude': -79.8495236914621,
#   'name': 'Delaware at Myrtle',
#   'timestamp': '2023-08-30T01:32:48.769000Z'},
#  {'empty_slots': 10,
#   'extra': {'address': '71, Maplewood Avenue, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_613'},
#   'free_bikes': 3,
#   'id': '24293855f2bcc6f090accfa582724fb9',
#   'latitude': 43.245150946389735,
#   'longitude': -79.83708053827286,
#   'name': 'Maplewood at Springer',
#   'timestamp': '2023-08-30T01:32:48.770000Z'},
#  {'empty_slots': 8,
#   'extra': {'address': '72 Harvey Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_610'},
#   'free_bikes': 4,
#   'id': '7b70b7a710103141733a20c8576088a7',
#   'latitude': 43.25504613306136,
#   'longitude': -79.84128892421722,
#   'name': 'Cannon at Birch (Powell Park)',
#   'timestamp': '2023-08-30T01:32:48.770000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '61-65 Sherman Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_611'},
#   'free_bikes': 2,
#   'id': 'dcef5763f35983322b325eff54e9b11c',
#   'latitude': 43.2533992835566,
#   'longitude': -79.8374917817979,
#   'name': 'Cannon at Sherman',
#   'timestamp': '2023-08-30T01:32:48.771000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '25 York Boulevard, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_708'},
#   'free_bikes': 2,
#   'id': '23a3650f250f263f047262bad48f9644',
#   'latitude': 43.25901059433612,
#   'longitude': -79.86919194459914,
#   'name': 'York at Macnab',
#   'timestamp': '2023-08-30T01:32:48.772000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': 'Stearn Drive, McMaster University, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_626'},
#   'free_bikes': 11,
#   'id': 'fcad722feba55f60aa8ef94f271d32bc',
#   'latitude': 43.26462232214244,
#   'longitude': -79.91868138313293,
#   'name': 'McMaster Stadium',
#   'timestamp': '2023-08-30T01:32:48.773000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '954 Barton Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2918'},
#   'free_bikes': 4,
#   'id': 'daa810a9a7ab64f657cbaa10b53791f9',
#   'latitude': 43.252910500996364,
#   'longitude': -79.82217215001583,
#   'name': 'Barton and Belview - ERI05',
#   'timestamp': '2023-08-30T01:32:48.774000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': '437-443 Ottawa Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2919'},
#   'free_bikes': 6,
#   'id': '75d70510a6ba5e0d9559620b06d7619f',
#   'latitude': 43.25147804372769,
#   'longitude': -79.81602117419243,
#   'name': 'Barton at Ottawa - ERI06',
#   'timestamp': '2023-08-30T01:32:48.776000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '151-163 Hamilton Regional Road 8, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_1397'},
#   'free_bikes': 4,
#   'id': '151be2bf06833b79e5c91f2f3b11cc30',
#   'latitude': 43.25519606248058,
#   'longitude': -79.86437804996967,
#   'name': 'King at Mary',
#   'timestamp': '2023-08-30T01:32:48.777000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '237-243 Cumberland Avenue, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_1252'},
#   'free_bikes': 3,
#   'id': '188b072a8eb403dc6a462878fc7211c4',
#   'latitude': 43.24333095563425,
#   'longitude': -79.84050840139389,
#   'name': 'Cumberland at Blake ',
#   'timestamp': '2023-08-30T01:32:48.778000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '700 Main Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_1253'},
#   'free_bikes': 8,
#   'id': 'dfaa61d3929e4c18b049cce2086faa26',
#   'latitude': 43.24814116192469,
#   'longitude': -79.84201848506926,
#   'name': 'Main at Eastbourne',
#   'timestamp': '2023-08-30T01:32:48.778000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '12-38 Blythe Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_597'},
#   'free_bikes': 9,
#   'id': '25e0a23ac089f5c5d951f4b5f26cf224',
#   'latitude': 43.2480282225403,
#   'longitude': -79.8550984051804,
#   'name': 'Stinson at Blythe',
#   'timestamp': '2023-08-30T01:32:48.781000Z'},
#  {'empty_slots': 14,
#   'extra': {'address': '203 Wentworth Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_596'},
#   'free_bikes': 0,
#   'id': '54ebd23b9e946b9644567796823f84ce',
#   'latitude': 43.24487936776345,
#   'longitude': -79.85186353325844,
#   'name': 'Wentworth Stairs',
#   'timestamp': '2023-08-30T01:32:48.782000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '4-12 Ferguson Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_591'},
#   'free_bikes': 7,
#   'id': '13e403b7b912d5c16f24a962a0dbf8f5',
#   'latitude': 43.2551792486624,
#   'longitude': -79.8614431097373,
#   'name': 'Ferguson at King William',
#   'timestamp': '2023-08-30T01:32:48.783000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '156, Cannon Street East, Beasley, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_590'},
#   'free_bikes': 5,
#   'id': 'bd95d2facb7bec4fd6c7c8928c941fb0',
#   'latitude': 43.2587508364231,
#   'longitude': -79.8598228455297,
#   'name': 'Ferguson at Cannon',
#   'timestamp': '2023-08-30T01:32:48.783000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': '286-300 Victoria Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_593'},
#   'free_bikes': 9,
#   'id': '93546ca33ce7f41d06721fc2dac2781c',
#   'latitude': 43.26124519046125,
#   'longitude': -79.853318631649,
#   'name': 'Victoria at Barton',
#   'timestamp': '2023-08-30T01:32:48.784000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '100 Mars Avenue, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2915'},
#   'free_bikes': 3,
#   'id': '4ec1cb16631106bd6374b5e61f694997',
#   'latitude': 43.26534015820083,
#   'longitude': -79.84364993870258,
#   'name': 'Mars at Wentworth - ERI01',
#   'timestamp': '2023-08-30T01:32:48.785000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '141-147 Sherman Avenue North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2916'},
#   'free_bikes': 5,
#   'id': '2c606a0f03e6e18f7c8684578b678158',
#   'latitude': 43.25632467316046,
#   'longitude': -79.83628392219543,
#   'name': 'Sherman at Barton - ERI02',
#   'timestamp': '2023-08-30T01:32:48.786000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '779-781 Barton Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2917'},
#   'free_bikes': 4,
#   'id': 'bae67560f54ae320890f86793feab2d8',
#   'latitude': 43.2552894386678,
#   'longitude': -79.83144521713257,
#   'name': 'Barton at Lottridge - ERI03',
#   'timestamp': '2023-08-30T01:32:48.786000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '174, Ferguson Avenue South, Corktown, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_599'},
#   'free_bikes': 7,
#   'id': '5e74f539b1fb571988571329de31f701',
#   'latitude': 43.2492552510953,
#   'longitude': -79.8641461491451,
#   'name': 'Corktown Park',
#   'timestamp': '2023-08-30T01:32:48.787000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '175, Hunter Street East, Corktown, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_598'},
#   'free_bikes': 4,
#   'id': 'f144a0bfeea43251601ea8efa4b701d2',
#   'latitude': 43.251798383773966,
#   'longitude': -79.86318781971931,
#   'name': 'Hunter at Ferguson',
#   'timestamp': '2023-08-30T01:32:48.788000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': 'Stearn Drive, McMaster University, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
# ...
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_562'},
#   'free_bikes': 7,
#   'id': '2c40c2c8f305bbdb55924286ef60a65e',
#   'latitude': 43.25332704523968,
#   'longitude': -79.886634349823,
#   'name': 'Charlton at Locke',
#   'timestamp': '2023-08-30T01:32:48.719000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '240-260 Herkimer Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5702'},
#   'free_bikes': 5,
#   'id': '136db3855339c99b874db87c997d2f46',
#   'latitude': 43.252499716928924,
#   'longitude': -79.88658607006073,
#   'name': 'Locke at Herkimer',
#   'timestamp': '2023-08-30T01:32:48.722000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '55 King William Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_904'},
#   'free_bikes': 6,
#   'id': '306cc88fcd5431a91806cc41757fb0c7',
#   'latitude': 43.2569048421661,
#   'longitude': -79.86643463373184,
#   'name': 'King William at Hughson',
#   'timestamp': '2023-08-30T01:32:48.800000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '501 Barton Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_603'},
#   'free_bikes': 4,
#   'id': '19f78245a8a7b0f415f83078efc45d26',
#   'latitude': 43.25893246012055,
#   'longitude': -79.8449581861496,
#   'name': 'Barton at Wentworth',
#   'timestamp': '2023-08-30T01:32:48.757000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': '195 Charlton Avenue West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_567'},
#   'free_bikes': 8,
#   'id': '672fa210a6d49cef4ada2f6cf610c352',
#   'latitude': 43.25200741706332,
#   'longitude': -79.88158643245697,
#   'name': 'Charlton at Queen',
#   'timestamp': '2023-08-30T01:32:48.717000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '180 James Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_903'},
#   'free_bikes': 2,
#   'id': 'bd18a5dc315913736a39a7a08144ce2f',
#   'latitude': 43.25163037518954,
#   'longitude': -79.87135380506516,
#   'name': 'Duke at James',
#   'timestamp': '2023-08-30T01:32:48.802000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '55 Elgin Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5790'},
#   'free_bikes': 3,
#   'id': '403cb92786f78feaeb7e07d11d225d28',
#   'latitude': 43.25891916811838,
#   'longitude': -79.86106485128403,
#   'name': 'Beasley Park',
#   'timestamp': '2023-08-30T01:32:48.704000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '16 John Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5827'},
#   'free_bikes': 1,
#   'id': 'c04d5fe44a7f100d1e87b3b7960ddc59',
#   'latitude': 43.25652795268133,
#   'longitude': -79.86623145639896,
#   'name': 'John near King',
#   'timestamp': '2023-08-30T01:32:48.775000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '137, Locke Street South, Hess Village, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_563'},
#   'free_bikes': 6,
#   'id': '0a044af8a55dabe96d0c48f86d744b2c',
#   'latitude': 43.256556155396176,
#   'longitude': -79.88510146737099,
#   'name': 'Locke at Hunter',
#   'timestamp': '2023-08-30T01:32:48.720000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '976 King Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5836'},
#   'free_bikes': 3,
#   'id': '151f2c238f193db179e8274b48aefa8f',
#   'latitude': 43.25124627968789,
#   'longitude': -79.83547054231167,
#   'name': 'King at Barnesdale',
#   'timestamp': '2023-08-30T01:32:48.766000Z'},
#  {'empty_slots': 4,
#   'extra': {'address': '924, King Street East, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5837'},
#   'free_bikes': 3,
#   'id': '60f1ff4162316df19c3fb9fbe498c62d',
#   'latitude': 43.2513467527978,
#   'longitude': -79.83823858201504,
#   'name': 'King at Sherman',
#   'timestamp': '2023-08-30T01:32:48.774000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '735, King Street East, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5838'},
#   'free_bikes': 6,
#   'id': '826039584ca9b60fd398e14cffdb03f9',
#   'latitude': 43.251884127702,
#   'longitude': -79.84635829925537,
#   'name': 'King at Sanford',
#   'timestamp': '2023-08-30T01:32:48.764000Z'},
#  {'empty_slots': 17,
#   'extra': {'address': '55 Bay Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_576'},
#   'free_bikes': 5,
#   'id': 'e4a63afc4502edf7569be3840617d71d',
#   'latitude': 43.25906138152248,
#   'longitude': -79.87338691949844,
#   'name': 'Bay at York',
#   'timestamp': '2023-08-30T01:32:48.699000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': '2-44 King Street West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5845'},
#   'free_bikes': 5,
#   'id': '37616366e445ace57088416e86786a61',
#   'latitude': 43.25693469264953,
#   'longitude': -79.86957684159279,
#   'name': 'Jackson Square',
#   'timestamp': '2023-08-30T01:32:48.780000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '400-408 Cannon Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5846'},
#   'free_bikes': 4,
#   'id': '81b2226a10ac65551fe73c9eedd02379',
#   'latitude': 43.25646071175471,
#   'longitude': -79.84998129308224,
#   'name': 'Cannon at Steven',
#   'timestamp': '2023-08-30T01:32:48.779000Z'},
#  {'empty_slots': 26,
#   'extra': {'address': '50 Leander Drive, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_960'},
#   'free_bikes': 3,
#   'id': '367f5ac4d324e57f25a59c0b3de3bd25',
#   'latitude': 43.27260051521549,
#   'longitude': -79.86689731478691,
#   'name': 'Pier 4',
#   'timestamp': '2023-08-30T01:32:48.721000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '4523 Ferguson Avenue South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_609'},
#   'free_bikes': 4,
#   'id': '89702be3edbe08f156bd7b3036f464d4',
#   'latitude': 43.25400491861888,
#   'longitude': -79.86223563551903,
#   'name': 'Ferguson at King',
#   'timestamp': '2023-08-30T01:32:48.761000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '250 Park Street South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_572'},
#   'free_bikes': 8,
#   'id': '397f2fea38d84b76656239ab6db8e407',
#   'latitude': 43.24978615747242,
#   'longitude': -79.87574994564056,
#   'name': 'Durand Park',
#   'timestamp': '2023-08-30T01:32:48.702000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '326, Cannon Street East, Beasley, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_594'},
#   'free_bikes': 4,
#   'id': 'ef756a7aa90c86940a92ba796032150e',
#   'latitude': 43.25729552525069,
#   'longitude': -79.85334813594818,
#   'name': 'Cannon at East',
#   'timestamp': '2023-08-30T01:32:48.781000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': '101 Strachan Street East, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_581'},
#   'free_bikes': 1,
#   'id': '4811838834c4e081dc82a8b015ae923a',
#   'latitude': 43.265938747249415,
#   'longitude': -79.86042380332947,
#   'name': 'Strachan at Mary',
#   'timestamp': '2023-08-30T01:32:48.794000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '282 MacNab Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_959'},
#   'free_bikes': 2,
#   'id': '209f28b67a835d95696b6166209907fb',
#   'latitude': 43.26624929442286,
#   'longitude': -79.86611008644103,
#   'name': 'West Harbour GO Station',
#   'timestamp': '2023-08-30T01:32:48.735000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '1 Guise Street West, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_924'},
#   'free_bikes': 2,
#   'id': 'a4efe67161d2b1ff1b28bd18c17f5196',
#   'latitude': 43.27365898786445,
#   'longitude': -79.86182928085327,
#   'name': 'James at Guise',
#   'timestamp': '2023-08-30T01:32:48.751000Z'},
#  {'empty_slots': 14,
#   'extra': {'address': 'Rock Garden @ RBG, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5883'},
#   'free_bikes': 0,
#   'id': '526a984471e6dbeb0a5037ede184360f',
#   'latitude': 43.289479198281,
#   'longitude': -79.89169299602507,
#   'name': 'RBG Rock Garden',
#   'timestamp': '2023-08-30T01:32:48.745000Z'},
#  {'empty_slots': 12,
#   'extra': {'address': '595 Catharine Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_5903'},
#   'free_bikes': 3,
#   'id': '55c7dd2953d457e587c7c9d092bf1cb2',
#   'latitude': 43.27528883070137,
#   'longitude': -79.85690742731094,
#   'name': 'Pier 8',
#   'timestamp': '2023-08-30T01:32:48.709000Z'},
#  {'empty_slots': 11,
#   'extra': {'address': '9 Westinghouse Avenue, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_2926'},
#   'free_bikes': 2,
#   'id': '4b4ce0df11a6f9cf3fc6e04e94c78828',
#   'latitude': 43.25831920066756,
#   'longitude': -79.84240606427193,
#   'name': 'Westinghouse at Barton - ERI13',
#   'timestamp': '2023-08-30T01:32:48.711000Z'},
#  {'empty_slots': 11,
#   'extra': {'address': '295 James Street North, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_608'},
#   'free_bikes': 2,
#   'id': '88b4283638e2beb669e4fe1bee89c2f6',
#   'latitude': 43.2637774120007,
#   'longitude': -79.8660421593136,
#   'name': 'James at Colbourne',
#   'timestamp': '2023-08-30T01:32:48.762000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': '122 Longwood Road South, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_553'},
#   'free_bikes': 8,
#   'id': '8b7317cc71a48fcac26a3ebcd4da7f25',
#   'latitude': 43.25960441109783,
#   'longitude': -79.90210264921188,
#   'name': 'Main at Longwood',
#   'timestamp': '2023-08-30T01:32:48.728000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': 'Waterfront Trail, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_1042'},
#   'free_bikes': 7,
#   'id': 'b745b74c5f9f41debda6ab80a7d9d2ac',
#   'latitude': 43.26000777328068,
#   'longitude': -79.7663875669241,
#   'name': "Van Wagner's Beach",
#   'timestamp': '2023-08-30T01:32:48.767000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': '39 King William Street, Hamilton',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_6148'},
#   'free_bikes': 2,
#   'id': 'c42abe3bb92ca77c23b2d7bfb49a21bc',
#   'latitude': 43.25763541749527,
#   'longitude': -79.86848652362822,
#   'name': 'King William at James',
#   'timestamp': '2023-08-30T01:32:48.720000Z'},
#  {'empty_slots': 0,
#   'extra': {'address': '2, Paisley Avenue South, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_6156'},
#   'free_bikes': 11,
#   'id': '07cdf0ecc542669b685cfebafb3ce797',
#   'latitude': 43.26171202317612,
#   'longitude': -79.90590065717697,
#   'name': 'Westdale Village - Paisley',
#   'timestamp': '2023-08-30T01:32:48.763000Z'},
#  {'empty_slots': 7,
#   'extra': {'address': '85, Oak Knoll Drive, Westdale, Hamilton, Ontario',
#    'last_updated': 1693355460,
#    'payment': ['key',
#     'applepay',
#     'androidpay',
#     'transitcard',
#     'accountnumber',
#     'phone'],
#    'payment-terminal': False,
#    'renting': 1,
#    'returning': 1,
#    'uid': 'hub_6157'},
#   'free_bikes': 1,
#   'id': '45fddcb389047d2db3720be4f59e37c7',
#   'latitude': 43.26486897083389,
#   'longitude': -79.90748047828674,
#   'name': 'Westdale Aviary',
#   'timestamp': '2023-08-30T01:32:48.763000Z'}]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
# Create a df out of the data that was saved in JSON format
hamilton_citybike_df = pd.DataFrame(hamilton_citybike_json['network']['stations'])

# %%
print(hamilton_citybike_df)
# Out:
#      empty_slots                                              extra  \
# 0              6  {'address': '15 Hess Street North, Hamilton', ...
# 1             23  {'address': 'Harbour Front Drive, North End, H...
# 2             25  {'address': '325 Bay Street North, Hamilton', ...
# 3              9  {'address': '177, Bay Street North, Hess Villa...
# 4             10  {'address': '58 Bay Street South, Hamilton', '...
# ..           ...                                                ...
# 139            1  {'address': '122 Longwood Road South, Hamilton...
# 140            6  {'address': 'Waterfront Trail, Hamilton', 'las...
# 141            3  {'address': '39 King William Street, Hamilton'...
# 142            0  {'address': '2, Paisley Avenue South, Westdale...
# 143            7  {'address': '85, Oak Knoll Drive, Westdale, Ha...
#
#      free_bikes                                id   latitude  longitude  \
# 0             6  45dbb0009135e465f49f054517cbe74d  43.259126 -79.877212
# 1            11  cd881edad122a75c57d94b381cdfc6c0  43.269288 -79.871327
# 2             0  024a3edf037cb411d16acc08a7fcb954  43.267859 -79.867923
# 3             5  b933317ff2861c45aacbea4cbf4b541f  43.263198 -79.871803
# 4             7  20dc109608315db09a8332d6e6940c75  43.256132 -79.874499
# ..          ...                               ...        ...        ...
# 139           8  8b7317cc71a48fcac26a3ebcd4da7f25  43.259604 -79.902103
# 140           7  b745b74c5f9f41debda6ab80a7d9d2ac  43.260008 -79.766388
# 141           2  c42abe3bb92ca77c23b2d7bfb49a21bc  43.257635 -79.868487
# 142          11  07cdf0ecc542669b685cfebafb3ce797  43.261712 -79.905901
# 143           1  45fddcb389047d2db3720be4f59e37c7  43.264869 -79.907480
#
#                            name                    timestamp
# 0                  Hess at king  2023-08-30T01:32:48.695000Z
# 1                 Bayfront Park  2023-08-30T01:32:48.697000Z
# 2               Bay at Strachan  2023-08-30T01:32:48.698000Z
# 3               Bay at Mulberry  2023-08-30T01:32:48.698000Z
# 4                     City Hall  2023-08-30T01:32:48.700000Z
# ..                          ...                          ...
# 139            Main at Longwood  2023-08-30T01:32:48.728000Z
# 140          Van Wagner's Beach  2023-08-30T01:32:48.767000Z
# 141       King William at James  2023-08-30T01:32:48.720000Z
# 142  Westdale Village - Paisley  2023-08-30T01:32:48.763000Z
# 143             Westdale Aviary  2023-08-30T01:32:48.763000Z
#
# [144 rows x 8 columns]

# %%
# Create a column that contains the total amount of bikes at each station
hamilton_citybike_df['total_bikes'] = hamilton_citybike_df['empty_slots'] + hamilton_citybike_df['free_bikes']

# %%
def addresses(address_series):
    """Extracts the address from the extras column"""
    return address_series['address']

# %%
hamilton_citybike_df['address'] = hamilton_citybike_df['extra'].apply(addresses)

# %%
# The address for each station was extracted from the 'extra' column so it can now be dropped
hamilton_citybike_df.drop(columns='extra', inplace=True)

# %%
print(hamilton_citybike_df.head())
# Out:
#    empty_slots  free_bikes                                id   latitude  \
# 0            6           6  45dbb0009135e465f49f054517cbe74d  43.259126
# 1           23          11  cd881edad122a75c57d94b381cdfc6c0  43.269288
# 2           25           0  024a3edf037cb411d16acc08a7fcb954  43.267859
# 3            9           5  b933317ff2861c45aacbea4cbf4b541f  43.263198
# 4           10           7  20dc109608315db09a8332d6e6940c75  43.256132
#
#    longitude             name                    timestamp  total_bikes  \
# 0 -79.877212     Hess at king  2023-08-30T01:32:48.695000Z           12
# 1 -79.871327    Bayfront Park  2023-08-30T01:32:48.697000Z           34
# 2 -79.867923  Bay at Strachan  2023-08-30T01:32:48.698000Z           25
# 3 -79.871803  Bay at Mulberry  2023-08-30T01:32:48.698000Z           14
# 4 -79.874499        City Hall  2023-08-30T01:32:48.700000Z           17
#
#                                              address
# 0                     15 Hess Street North, Hamilton
# 1  Harbour Front Drive, North End, Hamilton, Ontario
# 2                     325 Bay Street North, Hamilton
# 3  177, Bay Street North, Hess Village, Hamilton,...
# 4                      58 Bay Street South, Hamilton

# %%
# Save the df to a csv for the next part
hamilton_citybike_df.to_csv('../data/hamilton_citybike.csv')
